# %% [markdown]
# <a href="https://colab.research.google.com/github/wadizzo79/web-portfolio/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
x = requests.get('https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly?lat=35.5&lon=-78.5&units=imperial&lang=en')
print(x)
# Out:
# <Response [401]>
